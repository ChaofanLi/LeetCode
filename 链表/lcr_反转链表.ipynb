# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        res=None
        while head:
            temp=ListNode(head.val)
            temp.next=res
            res=temp
            head=head.next
        return res

# %% [markdown]
# ![image.png](attachment:image.png)
