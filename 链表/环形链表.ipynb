# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def hasCycle(self, head) -> bool:
        fast=head
        slow=head
        while True:
            if not fast or not fast.next:
                return False
            fast=fast.next.next
            slow=slow.next
            if slow==fast:
                return True

# %% [markdown]
# ![image.png](attachment:image.png)
